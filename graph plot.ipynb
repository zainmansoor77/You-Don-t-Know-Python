# %% [markdown]
# # graph plot

# %%
import matplotlib.pyplot as plt
y = [108.7,110.4,112.5,116.1,116.6,117.1,119.0]
x = [36.1,42.0,45.2,50,55,60,65]
plt.plot(x,y,marker = 'o')
plt.xlabel("Temperature in C")
plt.ylabel("Resistance in ohm")
plt.title("RTD temp vs resis")
plt.grid()
plt.show()

# %%
import numpy as np
import pylab
Polynomial = np.polynomial.Polynomial

y = np.array([108.7,110.4,112.5,116.1,116.6,117.1,119.0])
x = np.array([36.1,42.0,45.2,50,55,60,65])
cmin, cmax = min(x), max(x)
pfit, stats = Polynomial.fit(x, y, 1, full=True, window=(cmin, cmax),domain=(cmin, cmax))
pylab.plot(x, y, 'o', color='k')
pylab.plot(x, pfit(x), color='k')
pylab.xlabel("Temperature in C")
pylab.ylabel("Resistance in ohm")
pylab.title("RTD temp vs resis")
pylab.grid()
pylab.show()

# %%
import numpy as np 
from scipy.optimize import curve_fit 
from matplotlib import pyplot as plt 
import math
   
 
a = [1.037,1.041,1.041,1.088,1.088,1.075,1.083] #ptc   
b = [7.35,6.52,5.87,4.88,4.35,4.2,3.649]        #ntc
y1 = list()
#x1 = list()
y2 = list()
#x2 = list()
x = [36.1,42.0,45.2,50,55,60,65]


for i in range(7):
    y1.append(np.log10(a[i])) #ptc
    y2.append(np.log10(b[i])) #ntc
 
param_cov = curve_fit(x, y) 
print(y1)
print(y2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-41077a05a140> in <module>
#      18     y2.append(np.log10(b[i])) #ntc
#      19
# ---> 20 param_cov = curve_fit(x, y)
#      21 print(y1)
#      22 print(y2)
#
# TypeError: curve_fit() missing 1 required positional argument: 'ydata'

# %%
from numpy import linspace
from numpy.random import randn
from pymodelfit import QuadraticModel
from matplotlib import pyplot as plt

a = [1.037,1.041,1.041,1.088,1.088,1.075,1.083] #ptc   
b = [7.35,6.52,5.87,4.88,4.35,4.2,3.649]        #ntc
y1 = list()
#x1 = list()
y2 = list()
#x2 = list()
x = [36.1,42.0,45.2,50,55,60,65]


for i in range(7):
    y1.append(np.log10(a[i])) #ptc
    y2.append(np.log10(b[i])) #ntc
 
print(y1)
print(y2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-56-5516391ee259> in <module>
#       1 from numpy import linspace
#       2 from numpy.random import randn
# ----> 3 from pymodelfit import QuadraticModel
#       4 from matplotlib import pyplot as plt
#       5
#
# ModuleNotFoundError: No module named 'pymodelfit'
